# %%
import pandas as pd
import requests as rq

# %%
#Grab the data from the server, must use my API Key
r = rq.get('https://api.data.gov/ed/collegescorecard/v1/schools.json?api_key=KYthZktaAwB5CMGp9Keyl3raXpb6CS43CaMhbLkr&school.name=Iowa%20State%20University')
data = r.json()
df = pd.DataFrame.from_dict(data['results'])
df
# Out:
#                                                 1996  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 1997  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 1998  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 1999  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2000  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2001  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2002  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2003  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2004  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2005  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                          ...                          \
# 0                        ...
#
#                                                 2013  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2014  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2015  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                                 2016      id  \
# 0  {'completion': {'completion_rate_lt_four_year_...  153603
#
#                                               latest  \
# 0  {'completion': {'completion_rate_lt_four_year_...
#
#                                 location ope6_id ope8_id  \
# 0  {'lon': -93.648504, 'lat': 42.026212}    1869  186900
#
#                                               school
# 0  {'degrees_awarded': {'predominant': 3, 'highes...
#
# [1 rows x 27 columns]

# %%
#segment the data into subsets
segmentList = [
data['results'][0]['2012']['completion'],
data['results'][0]['2012']['earnings'],
data['results'][0]['2012']['student'],
data['results'][0]['2012']['admissions'],
data['results'][0]['2012']['aid'],
data['results'][0]['2012']['repayment'],
]

# %%
completion2012 = segmentList[0]
earnings2012 = segmentList[1]
students2012 = segmentList[2]
admissions2012 = segmentList[3]
aid2012 = segmentList[4]
repayment2012 = segmentList[5]

# %%
completion2012
# Out:
# {'completion_rate_lt_four_year_100_pooled': None,
#  'pooled_yrs_used_200': None,
#  'completion_cohort_4yr_150_black_pre2010': None,
#  'completion_cohort_4yr_150_aian': 10,
#  'completion_rate_lt_four_year_150_loan_nopell': None,
#  '8_yr_completion': {'no_pell_grant': 2308,
#   'high_income': 1420,
#   'no_first_generation_students': 3041,
#   'first_generation_students': 1111,
#   'middle_income': 1688,
#   'pell_grant': 1844,
#   'dependent_students': 3677,
#   'male_students': 2228,
#   'no_loan_students': 137,
#   'independent_students': 475,
#   'female_students': 1924,
#   'overall': 4152,
#   'low_income': 1044,
#   'loan_students': 4015},
#  'completion_cohort_less_than_4yr_150nt_pooled': None,
#  'completion_rate_less_than_4yr_200nt_pooled': None,
#  'completion_rate_4yr_150_api_pre2010': None,
#  'completion_rate_four_year_100_pooled': None,
#  'completion_rate_l4yr_150_hispanic': None,
#  'completion_cohort_less_than_4yr_150_nhpi': None,
#  'completion_rate_four_year_150_noloan_nopell': None,
#  'completion_cohort_4yr_150nt': 3933,
#  'completion_rate_l4yr_150_aian': None,
#  'completion_cohort_4yr_150nt_pooled': None,
#  'completion_cohort_four_year_100_pooled': None,
#  '3_yr_completion': {'no_pell_grant': 2413,
#   'high_income': 2118,
#   'no_first_generation_students': 3500,
#   'first_generation_students': 1228,
#   'middle_income': 1538,
#   'pell_grant': 2315,
#   'dependent_students': 4196,
#   'male_students': 2577,
#   'no_loan_students': 241,
#   'independent_students': 532,
#   'female_students': 2151,
#   'overall': 4728,
#   'low_income': 1072,
#   'loan_students': 4487},
#  'completion_rate_less_than_4yr_200nt': None,
#  'completion_rate_four_year_150_loan_nopell': None,
#  'completion_rate_4yr_150_race': {'unknown': 0.6557},
#  'completion_rate_4yr_150_asian': 0.7664,
#  'completion_rate_4yr_150_black': 0.5,
#  'completion_rate_4yr_150_hispanic_pre2010': None,
#  'completion_cohort_less_than_4yr_150_aian': None,
#  'rate_suppressed': {'lt_four_year': None,
#   'overall': None,
#   'four_year_100_pooled': None,
#   'four_year': None,
#   'four_year_200percent': None,
#   'lt_four_year_150percent': None,
#   'lt_four_year_100_pooled': None},
#  'completion_cohort_4yr_150_black': 116,
#  'completion_rate_l4yr_150_nhpi': None,
#  'completion_cohort_less_than_4yr_100nt': None,
#  'completion_rate_l4yr_150_white': None,
#  'completion_cohort_4yr_100nt': 3933,
#  'completion_rate_l4yr_150_api_pre2010': None,
#  'completion_rate_l4yr_150_asian': None,
#  'completion_rate_l4yr_150_white_pre2010': None,
#  'transfer_rate': {'cohort_4yr': {'full_time': 3933, 'full_time_pooled': None},
#   'cohort_less_than_4yr': {'full_time': None, 'full_time_pooled': None},
#   'less_than_4yr': {'full_time': None, 'full_time_pooled': None},
#   '4yr': {'full_time': 0.23137554030002, 'full_time_pooled': None}},
#  '6_yr_completion': {'no_pell_grant': 2175,
#   'high_income': 1546,
#   'no_first_generation_students': 2954,
#   'first_generation_students': 1036,
#   'middle_income': 1478,
#   'pell_grant': 1815,
#   'dependent_students': 3569,
#   'male_students': 2166,
#   'no_loan_students': 124,
#   'independent_students': 421,
#   'female_students': 1824,
#   'overall': 3990,
#   'low_income': 966,
#   'loan_students': 3866},
#  'completion_cohort_4yr_150_white_pre2010': None,
#  'completion_cohort_lt_four_year_150_pell': None,
#  'completion_rate_4yr_150nt': 0.7079,
#  'completion_rate_4yr_150_nonresident': {'alien': 0.6833},
#  'completion_rate_4yr_200nt_pooled': None,
#  'completion_cohort_less_than_4yr_150_api_pre2010': None,
#  'completion_cohort_lt_four_year_150_loan_nopell': None,
#  'completion_cohort_less_than_4yr_150nt': None,
#  'completion_rate_4yr_150_white': 0.7182,
#  'completion_rate_four_year_150_pell': None,
#  'completion_rate_less_than_4yr_150nt_pooled': None,
#  'completion_rate_4yr_100nt': 0.38774472412916,
#  'completion_rate_lt_four_year_150_pell': None,
#  'outcome_percentage': {'part_time': {'first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'transfer': None,
#      'award': None,
#      'unknown_pooled': None,
#      'still_enrolled': None,
#      'award_pooled': None,
#      'unknown': None},
#     '6yr': {'award': None, 'award_pooled': None}},
#    'not_first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'transfer': None,
#      'award': None,
#      'unknown_pooled': None,
#      'still_enrolled': None,
#      'award_pooled': None,
#      'unknown': None},
#     '6yr': {'award': None, 'award_pooled': None}}},
#   'full_time': {'first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'transfer': None,
#      'award': None,
#      'unknown_pooled': None,
#      'still_enrolled': None,
#      'award_pooled': None,
#      'unknown': None},
#     '6yr': {'award': None, 'award_pooled': None}},
#    'not_first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'transfer': None,
#      'award': None,
#      'unknown_pooled': None,
#      'still_enrolled': None,
#      'award_pooled': None,
#      'unknown': None},
#     '6yr': {'award': None, 'award_pooled': None}}}},
#  'completion_cohort_less_than_4yr_150_white_pre2010': None,
#  'completion_cohort_4yr_150_asian': 137,
#  'completion_rate_4yr_150_aian_pre2010': None,
#  'completion_cohort_four_year_150_pell': None,
#  '4_yr_completion': {'no_pell_grant': 2467,
#   'high_income': 2021,
#   'no_first_generation_students': 3463,
#   'first_generation_students': 1177,
#   'middle_income': 1657,
#   'pell_grant': 2173,
#   'dependent_students': 4160,
#   'male_students': 2482,
#   'no_loan_students': 213,
#   'independent_students': 480,
#   'female_students': 2158,
#   'overall': 4640,
#   'low_income': 962,
#   'loan_students': 4427},
#  'completion_cohort_4yr_150_race': {'unknown': 122},
#  'completion_cohort_lt_four_year_100_pooled': None,
#  'completion_cohort_less_than_4yr_150_nonresident': {'alien': None},
#  'completion_cohort_4yr_150_hispanic': 123,
#  'transfer_rate_suppressed': {'less_than_4yr': {'full_time_pooled': None},
#   '4yr': {'full_time_pooled': None}},
#  'completion_rate_4yr_150_nhpi': None,
#  'completion_rate_l4yr_150_aian_pre2010': None,
#  'completion_cohort_less_than_4yr_150_white': None,
#  'completion_rate_less_than_4yr_150nt': None,
#  'completion_cohort_4yr_150_2ormore': 15,
#  'completion_rate_4yr_150_white_pre2010': None,
#  'completion_rate_l4yr_150_black_pre2010': None,
#  'completion_cohort_less_than_4yr_150_asian': None,
#  'completion_rate_l4yr_150_race': {'unknown': None},
#  'completion_rate_4yr_150_hispanic': 0.6179,
#  'completion_cohort_less_than_4yr_150_race': {'unknown': None},
#  'separation_date': {'number': 9946, 'median': '05/08/2015'},
#  'completion_rate_4yr_150_black_pre2010': None,
#  'completion_cohort_four_year_150_loan_nopell': None,
#  'completion_cohort_4yr_200nt': 3661.0,
#  'completion_rate_less_than_4yr_100nt': None,
#  'completion_cohort_less_than_4yr_150_2ormore': None,
#  'completion_cohort_less_than_4yr_200nt': None,
#  'completion_rate_4yr_150_2ormore': 0.8667,
#  'completion_rate_4yr_150_aian': 0.5,
#  '2_yr_completion': {'no_pell_grant': 2360,
#   'high_income': 2080,
#   'no_first_generation_students': 3554,
#   'first_generation_students': 1131,
#   'middle_income': 1532,
#   'pell_grant': 2325,
#   'dependent_students': 4175,
#   'male_students': 2409,
#   'no_loan_students': 256,
#   'independent_students': 510,
#   'female_students': 2276,
#   'overall': 4685,
#   'low_income': 1073,
#   'loan_students': 4429},
#  'pooled_yrs_used': None,
#  'completion_cohort_less_than_4yr_150_black': None,
#  'completion_cohort_4yr_200nt_pooled': None,
#  'pooled_yrs_used_100': None,
#  'completion_cohort_4yr_150_api_pre2010': None,
#  'completion_rate_4yr_150nt_pooled': None,
#  'completion_cohort_4yr_150_nhpi': 0,
#  'completion_cohort_less_than_4yr_150_black_pre2010': None,
#  'completion_rate_l4yr_150_black': None,
#  'outcome_percentage_suppressed': {'part_time': {'first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'unknown_pooled': None,
#      'award_pooled': None},
#     '6yr': {'award_pooled': None}},
#    'not_first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'unknown_pooled': None,
#      'award_pooled': None},
#     '6yr': {'award_pooled': None}}},
#   'full_time': {'first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'unknown_pooled': None,
#      'award_pooled': None},
#     '6yr': {'award_pooled': None}},
#    'not_first_time': {'8yr': {'transfer_pooled': None,
#      'still_enrolled_pooled': None,
#      'unknown_pooled': None,
#      'award_pooled': None},
#     '6yr': {'award_pooled': None}}}},
#  'completion_rate_l4yr_150_hispanic_pre2010': None,
#  'completion_cohort_less_than_4yr_150_hispanic': None,
#  'completion_cohort_lt_four_year_150_noloan_nopell': None,
#  'completion_rate_l4yr_150_nonresident': {'alien': None},
#  'completion_cohort_4yr_150_nonresident': {'alien': 60},
#  'completion_rate_lt_four_year_150_noloan_nopell': None,
#  'completion_cohort_four_year_150_noloan_nopell': None,
#  'completion_rate_4yr_200nt': 0.7238,
#  'outcome_years': {'part_time': {'first_time': None, 'not_first_time': None},
#   'full_time': {'first_time': None, 'not_first_time': None}},
#  'completion_rate_l4yr_150_2ormore': None,
#  'outcome_cohort': {'part_time': {'first_time': {'6yr_pooled': None,
#     '8yr': None,
#     '8yr_pooled': None,
#     '6yr': None},
#    'not_first_time': {'6yr_pooled': None,
#     '8yr': None,
#     '8yr_pooled': None,
#     '6yr': None}},
#   'full_time': {'first_time': {'6yr_pooled': None,
#     '8yr': None,
#     '8yr_pooled': None,
#     '6yr': None},
#    'not_first_time': {'6yr_pooled': None,
#     '8yr': None,
#     '8yr_pooled': None,
#     '6yr': None}}},
#  'completion_cohort_4yr_150_white': 3350,
#  'completion_cohort_less_than_4yr_200nt_pooled': None,
#  'title_iv': {'unknown_by': {'2yrs': 0.030096051,
#    '8yrs': 0.02938343,
#    '6yrs': 0.026566416,
#    '3yrs': 0.02643824,
#    '4yrs': 0.020258621},
#   'still_enrolled_by': {'2yrs': 0.500106724,
#    '8yrs': 0.004816956,
#    '6yrs': 0.00877193,
#    '3yrs': 0.253172589,
#    '4yrs': 0.065086207},
#   'depend': {'unknown_by': {'2yrs': None,
#     '8yrs': 0.025020397,
#     '6yrs': 0.023255814,
#     '3yrs': 0.024308866,
#     '4yrs': 0.014903846},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.050538922,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'still_enrolled_by': {'2yrs': 0.528622755,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': 0.265729266,
#     '4yrs': 0.067307692},
#    'withdrawn_by': {'2yrs': 0.094850299,
#     '8yrs': 0.095186293,
#     '6yrs': 0.082376016,
#     '3yrs': 0.094375596,
#     '4yrs': 0.092788462},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.045988024,
#     '8yrs': 0.04541746,
#     '6yrs': 0.046231437,
#     '3yrs': 0.056959009,
#     '4yrs': 0.059855769},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '8yrs': 0.078596682,
#     '6yrs': 0.070047632,
#     '3yrs': 0.02478551,
#     '4yrs': 0.047596154},
#    'died_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': 0.018682635,
#     '8yrs': 0.044601577,
#     '6yrs': 0.041188008,
#     '3yrs': 0.022878932,
#     '4yrs': 0.031490385},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': 0.02633791,
#     '3yrs': 0.023117255,
#     '4yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.103952096,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': 0.064585319,
#     '4yrs': None},
#    'completed_by': {'2yrs': 0.103233533,
#     '8yrs': 0.654065815,
#     '6yrs': 0.671056318,
#     '3yrs': 0.385843661,
#     '4yrs': 0.595913462}},
#   'mid_inc': {'unknown_by': {'2yrs': 0.033942559,
#     '8yrs': 0.017772512,
#     '6yrs': 0.0202977,
#     '3yrs': 0.024057217,
#     '4yrs': 0.016294508},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.054177546,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': 0.026657997,
#     '4yrs': 0.016898008},
#    'still_enrolled_by': {'2yrs': 0.481070496,
#     '8yrs': None,
#     '6yrs': 0.00947226,
#     '3yrs': 0.249674903,
#     '4yrs': 0.063971032},
#    'withdrawn_by': {'2yrs': 0.109660574,
#     '8yrs': 0.110189574,
#     '6yrs': 0.102165088,
#     '3yrs': 0.103381014,
#     '4yrs': 0.112854556},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '8yrs

#    'transf_unknown_2yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.082150538,
#     '8yrs': 0.00867679,
#     '6yrs': 0.013223141,
#     '3yrs': 0.053563715,
#     '4yrs': 0.024390244},
#    'completed_by': {'2yrs': 0.136344086,
#     '8yrs': 0.635032538,
#     '6yrs': 0.657300276,
#     '3yrs': 0.368034557,
#     '4yrs': 0.571099862}},
#   'male': {'unknown_by': {'2yrs': 0.03445413,
#     '8yrs': 0.036804309,
#     '6yrs': 0.028162512,
#     '3yrs': 0.027551416,
#     '4yrs': 0.024979855},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.049813201,
#     '8yrs': None,
#     '6yrs': 0.00877193,
#     '3yrs': 0.02677532,
#     '4yrs': 0.012892828},
#    'still_enrolled_by': {'2yrs': 0.512660855,
#     '8yrs': None,
#     '6yrs': 0.00923361,
#     '3yrs': 0.286767559,
#     '4yrs': 0.088235294},
#    'withdrawn_by': {'2yrs': 0.129514321,
#     '8yrs': 0.119389587,
#     '6yrs': 0.108033241,
#     '3yrs': 0.128443927,
#     '4yrs': 0.119661563},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.052303861,
#     '8yrs': 0.049820467,
#     '6yrs': 0.054478301,
#     '3yrs': 0.061699651,
#     '4yrs': 0.067687349},
#    'transf_completed_4yr_by': {'2yrs': 0.00456621,
#     '8yrs': 0.072262119,
#     '6yrs': 0.056325023,
#     '3yrs': 0.016298021,
#     '4yrs': 0.037066882},
#    'died_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': 0.01867995,
#     '8yrs': 0.050718133,
#     '6yrs': 0.040627886,
#     '3yrs': 0.025223128,
#     '4yrs': 0.037066882},
#    'transf_completed_2yr_by': {'2yrs': 0.0124533,
#     '8yrs': 0.02513465,
#     '6yrs': 0.023084026,
#     '3yrs': 0.023282887,
#     '4yrs': 0.025785657},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '8yrs': None,
#     '6yrs': None,
#     '3yrs': None,
#     '4yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.077625571,
#     '8yrs': 0.008976661,
#     '6yrs': 0.012927055,
#     '3yrs': 0.063251843,
#     '4yrs': 0.032232071},
#    'completed_by': {'2yrs': 0.102117061,
#     '8yrs': 0.614452424,
#     '6yrs': 0.647737766,
#     '3yrs': 0.330616997,
#     '4yrs': 0.546736503}}}}

# %%
earnings2012
# Out:
# {'6_yrs_after_entry': {'working_not_enrolled': {'income': {'lowest_tercile': 1142,
#     'middle_tercile': 1697,
#     'highest_tercile': 3205},
#    'dependent_students_lowest_tercile': None,
#    'std_dev': 25600,
#    'mean_earnings': 41000,
#    'overall': 6044,
#    'earnings_percentile': {'25': 26400, '90': None, '75': 52200, '10': None},
#    'dependent_students': 5425},
#   'percent_greater_than_28000': None,
#   'independent_students': 619,
#   'median': 37800,
#   'mean_earnings': {'independent_students': 40900.0,
#    'dependent_students_lowest_tercile': None,
#    'lowest_tercile': 39900.0,
#    'middle_tercile': 40200.0,
#    'female_students': 35000.0,
#    'highest_tercile': 41800.0,
#    'male_students': 45600.0,
#    'dependent_students': 41000.0},
#   'percent_greater_than_25000': 0.774,
#   'female_students': 2634,
#   'not_working_not_enrolled': {'overall': 299},
#   'male_students': 3410},
#  'student_count': None,
#  '8_yrs_after_entry': {'working_not_enrolled': 6475,
#   'median_earnings': 43600.0,
#   '25th_percentile_earnings': 30300,
#   'percent_greater_than_28000': None,
#   '90th_percentile_earnings': None,
#   '75th_percentile_earnings': 60700,
#   'mean_earnings': 47600.0,
#   '10th_percentile_earnings': None,
#   'percent_greater_than_25000': 0.827,
#   'std_deviation': 29000.0,
#   'not_working_not_enrolled': 410},
#  '10_yrs_after_entry': {'working_not_enrolled': {'income': {'lowest_tercile': 1327,
#     'middle_tercile': 2264,
#     'highest_tercile': 3796},
#    'dependent_students_lowest_tercile': None,
#    'std_dev': 32900,
#    'mean_earnings': 52900,
#    'overall': 7387,
#    'earnings_percentile': {'25': 32900, '90': None, '75': 67900, '10': None},
#    'dependent_students': 6694},
#   'percent_greater_than_28000': None,
#   'independent_students': 693,
#   'median': 47800,
#   'mean_earnings': {'independent_students': 48500,
#    'dependent_students_lowest_tercile': None,
#    'lowest_tercile': 49800,
#    'middle_tercile': 51600,
#    'female_students': 44600,
#    'highest_tercile': 54800,
#    'male_students': 59600,
#    'dependent_students': 53400},
#   'percent_greater_than_25000': 0.844,
#   'female_students': 3285,
#   'not_working_not_enrolled': {'overall': 563},
#   'male_students': 4102},
#  '7_yrs_after_entry': {'working_not_enrolled': None,
#   'std_dev': None,
#   'mean_earnings': None,
#   'percent_greater_than_25000': None,
#   'not_working_not_enrolled': None},
#  '9_yrs_after_entry': {'working_not_enrolled': None,
#   'mean_earnings': None,
#   'percent_greater_than_25000': None,
#   'std_deviation': None,
#   'not_working_not_enrolled': None}}

# %%
students2012
# Out:
# {'students_with_pell_grant': 0.4713297318,
#  'valid_dependency_status': 10551,
#  'share_25_older': None,
#  'share_lowincome': {'0_30000': 0.1946734907},
#  'grad_students': 5195,
#  'share_dependent_lowincome': {'0_300000': 0.1321052632},
#  'family_income': {'independent_students': 1051,
#   'overall': 10551,
#   'dependent_students': 9500},
#  'avg_independent_income': {'2014dollars': 19552},
#  'share_dependent_highincome': {'110001plus': 0.3373684211,
#   '75001_110000': 0.2421052632},
#  'share_first': {'time_full': {'time': 0.74288885805466}},
#  'part_time_share': 0.0414,
#  'share_highincome': {'110001plus': 0.304710454, '75001_110000': 0.2204530376},
#  'part_time_share_2000': None,
#  'parents_education_level': 10122,
#  'share_independent_students': 0.0996114112,
#  'share_independent_highincome': {'110001plus': 0.0095147479,
#   '75001_110000': 0.0247383444},
#  'undergrads_with_pell_grant_or_federal_student_loan': 24343,
#  'share_middleincome': {'30001_48000': 0.1151549616,
#   '48001_75000': 0.1650080561},
#  'share_independent_middleincome': {'30001_48000': 0.1389153187,
#   '48001_75000': 0.066603235},
#  'share_firstgeneration': 0.2163604031,
#  'undergrads_non_degree_seeking': 495,
#  'enrollment': {'all': None},
#  'share_independent_lowincome': {'0_30000': 0.7602283539},
#  'share_firstgeneration_parents': {'somecollege': 0.7836395969,
#   'middleschool': 0.0095830863,
#   'highschool': 0.2067773167},
#  'retention_rate': {'lt_four_year': {'part_time': None,
#    'full_time': None,
#    'part_time_pooled': None,
#    'full_time_pooled': None},
#   'cohort': {'lt_four_year': {'part_time_pooled': None,
#     'full_time_pooled': None},
#    'four_year': {'part_time_pooled': None, 'full_time_pooled': None}},
#   'overall': {'full_time': 0.8579},
#   'pooled_yrs_used': {'part_time': None, 'full_time': None},
#   'four_year': {'part_time': 0.5238,
#    'full_time': 0.8579,
#    'part_time_pooled': None,
#    'full_time_pooled': None}},
#  'fafsa_sent': {'2_college_allyrs': 0.4311439674,
#   '3_college': None,
#   '5plus_college_allyrs': 0.0932613022,
#   '4_colleges': None,
#   '1_college': None,
#   'overall': None,
#   '2_colleges': None,
#   '3_college_allyrs': 0.2361861435,
#   '5_or_more_colleges': None,
#   '4_college_allyrs': 0.1472846176},
#  'size': 25058,
#  'share_dependent_middleincome': {'300001_48000': 0.1125263158,
#   '48001_75000': 0.1758947368},
#  'retention_rate_suppressed': {'lt_four_year': {'part_time_pooled': None,
#    'full_time_pooled': None},
#   'four_year': {'part_time_pooled': None, 'full_time_pooled': None}},
#  'avg_dependent_income': {'2014dollars': 88068},
#  'FAFSA_applications': 10551,
#  'demographics': {'share_asian': {'home_ZIP': None},
#   'race_ethnicity': {'nhpi': 0.0009,
#    'non_resident_alien': 0.0727,
#    'black_2000': None,
#    'aian_2000': None,
#    'hispanic_prior_2009': None,
#    'asian': 0.027,
#    'black': 0.0256,
#    'api_2000': None,
#    'hispanic_2000': None,
#    'unknown_2000': None,
#    'unknown': 0.0308,
#    'white_non_hispanic': None,
#    'black_non_hispanic': None,
#    'asian_pacific_islander': None,
#    'white': 0.7856,
#    'two_or_more': 0.0164,
#    'hispanic': 0.0389,
#    'aian': 0.0021,
#    'aian_prior_2009': None,
#    'white_2000': None},
#   'non_resident_aliens_2000': None,
#   'female_share': 0.4578712918,
#   'age_entry': 20,
#   'median_hh_income_log': None,
#   'share_born_US': {'home_ZIP': None},
#   'share_black': {'home_ZIP': None},
#   'median_hh_income': None,
#   'age_entry_squared': None,
#   'first_generation': 0.2163604031,
#   'men': 0.5646,
#   'share_professional_degree_age25': {'home_ZIP': None},
#   'dependent': 0.9003885888,
#   'avg_family_income_independents_log': None,
#   'avg_family_income_log': None,
#   'median_family_income': 71810,
#   'share_bachelors_degree_age25': {'home_ZIP': None},
#   'over_23_at_entry': None,
#   'share_hispanic': {'home_ZIP': None},
#   'poverty_rate': None,
#   'avg_family_income': 81243,
#   'veteran': 0.0034119989,
#   'unemployment': None,
#   'avg_family_income_independents': 19552,
#   'share_white': {'home_ZIP': None},
#   'married': 0.0279594351,
#   'women': 0.4354}}

# %%
admissions2012
# Out:
# {'sat_scores': {'average': {'overall': 1145.0, 'by_ope_id': 1145.0},
#   'midpoint': {'critical_reading': 555.0, 'writing': None, 'math': 590.0},
#   '25th_percentile': {'critical_reading': 480.0,
#    'writing': None,
#    'math': 520.0},
#   '75th_percentile': {'critical_reading': 630.0,
#    'writing': None,
#    'math': 660.0}},
#  'act_scores': {'midpoint': {'writing': None,
#    'english': 25.0,
#    'math': 25.0,
#    'cumulative': 25.0},
#   '25th_percentile': {'writing': None,
#    'english': 22.0,
#    'math': 21.0,
#    'cumulative': 22.0},
#   '75th_percentile': {'writing': None,
#    'english': 28.0,
#    'math': 28.0,
#    'cumulative': 28.0}},
#  'admission_rate': {'overall': 0.8625, 'by_ope_id': 0.8625}}

# %%
aid2012
# Out:
# {'pell_grant_rate': 0.2429,
#  'median_debt': {'no_pell_grant': 16500.0,
#   'income': {'30001_75000': 19000.0,
#    'greater_than_75000': 18438.0,
#    '0_30000': 16229.0},
#   'number': {'no_pell_grant': 5066,
#    'income': {'30001_75000': 3386,
#     'greater_than_75000': 4363,
#     '0_30000': 2229},
#    'noncompleters': 4056,
#    'independent_students': 1106,
#    'non_first_generation_students': 7619,
#    'completers': 5950,
#    'first_generation_students': 2359,
#    'female_students': 4535,
#    'overall': 9978,
#    'pell_grant': 4912,
#    'male_students': 5443,
#    'dependent_students': 8872},
#   'noncompleters': 6500.0,
#   'independent_students': 17827.0,
#   'non_first_generation_students': 18100.0,
#   'completers': {'overall': 25000.0, 'monthly_payments': None},
#   'first_generation_students': 18000.0,
#   'female_students': 18750.0,
#   'pell_grant': 19457.0,
#   'male_students': 17632.0,
#   'dependent_students': 18126.5},
#  'federal_loan_rate': 0.5646,
#  'students_with_any_loan': 0.9426594636,
#  'loan_principal': 18095.0,
#  'cumulative_debt': {'number': 9978,
#   '10th_percentile': 3500,
#   '90th_percentile': 33000,
#   '25th_percentile': 6500,
#   '75th_percentile': 27770},
#  'median_debt_suppressed': {'completers': {'overall': 25000.0,
#    'monthly_payments': None},
#   'overall': 18095.0}}

# %%
repayment2012
# Out:
# {'repayment_cohort': {'3_year_declining_balance': 0.7850716896,
#   '1_year_declining_balance': 0.7077252139,
#   '7_year_declining_balance': None,
#   '5_year_declining_balance': 0.8406470487},
#  '5_yr_repayment': {'income': {'greater_than_75000': 0.8793407887,
#    '0_30000': 0.7626561473,
#    '30000_75000': 0.8610575068},
#   'male_students_rate': 0.8407701711,
#   'high_income': 1699,
#   'completers': 2750,
#   'completers_rate': 0.9189090909,
#   'male_students': 3272,
#   'pell_grant_rate': 0.8090363572,
#   'noncompleters': 3061,
#   'noncompleters_rate': 0.7703364913,
#   'female_students': 2539,
#   'low_income': 1521,
#   'no_pell_grant_rate': 0.8707186031,
#   'female_students_rate': 0.8404883813,
#   'no_pell_grant': 2978,
#   'first_generation_students': 1563,
#   'middle_income': 2591,
#   'first_generation_students_rate': 0.8170185541,
#   'pell_grant': 2833,
#   'dependent_students': 5201,
#   'independent_students_rate': 0.6901639344,
#   'dependent_students_rate': 0.8582964814,
#   'independent_students': 610,
#   'non_first_generation_students_rate': 0.8493408663,
#   'non_first_generation_students': 4248,
#   'overall': 5811},
#  '2_yr_default_rate': 0.038,
#  '3_yr_repayment': {'income': {'greater_than_75000': 0.8317572892,
#    '0_30000': 0.6885833831,
#    '30000_75000': 0.7998622115},
#   'male_students_rate': 0.7842741935,
#   'high_income': 2538,
#   'completers': 4499,
#   'completers_rate': 0.8719715492,
#   'male_students': 3968,
#   'pell_grant_rate': 0.7203732504,
#   'noncompleters': 2615,
#   'noncompleters_rate': 0.6355640535,
#   'female_students': 3146,
#   'low_income': 1673,
#   'no_pell_grant_rate': 0.8384201077,
#   'female_students_rate': 0.7860775588,
#   'no_pell_grant': 3899,
#   'first_generation_students': 1768,
#   'middle_income': 2903,
#   'first_generation_students_rate': 0.7403846154,
#   'pell_grant': 3215,
#   'dependent_students': 6413,
#   'independent_students_rate': 0.5848787447,
#   'dependent_students_rate': 0.8069546234,
#   'independent_students': 701,
#   'non_first_generation_students_rate': 0.7998503554,
#   'non_first_generation_students': 5346,
#   'overall': 7114},
#  '7_yr_repayment': {'income': {'greater_than_75000': None,
#    '0_30000': None,
#    '30000_75000': None},
#   'male_students_rate': None,
#   'high_income': None,
#   'completers': None,
#   'completers_rate': None,
#   'male_students': None,
#   'pell_grant_rate': None,
#   'noncompleters': None,
#   'noncompleters_rate': None,
#   'female_students': None,
#   'low_income': None,
#   'no_pell_grant_rate': None,
#   'female_students_rate': None,
#   'no_pell_grant': None,
#   'first_generation_students': None,
#   'middle_income': None,
#   'first_generation_students_rate': None,
#   'pell_grant': None,
#   'dependent_students': None,
#   'independent_students_rate': None,
#   'dependent_students_rate': None,
#   'independent_students': None,
#   'non_first_generation_students_rate': None,
#   'non_first_generation_students': None,
#   'overall': None},
#  '1_yr_repayment': {'income': {'greater_than_75000': 0.7845181675,
#    '0_30000': 0.5517432208,
#    '30000_75000': 0.720766129},
#   'male_students_rate': 0.7216075864,
#   'high_income': 3165,
#   'completers': 5030,
#   'completers_rate': 0.802584493,
#   'male_students': 4429,
#   'pell_grant_rate': 0.6216,
#   'noncompleters': 2918,
#   'noncompleters_rate': 0.5442083619,
#   'female_students': 3519,
#   'low_income': 1807,
#   'no_pell_grant_rate': 0.7846593616,
#   'female_students_rate': 0.6902529128,
#   'no_pell_grant': 4198,
#   'first_generation_students': 1960,
#   'middle_income': 2976,
#   'first_generation_students_rate': 0.6510204082,
#   'pell_grant': 3750,
#   'dependent_students': 7086,
#   'independent_students_rate': 0.4837587007,
#   'dependent_students_rate': 0.7349703641,
#   'independent_students': 862,
#   'non_first_generation_students_rate': 0.7262859051,
#   'non_first_generation_students': 5988,
#   'overall': 7948},
#  '3_yr_default_rate': 0.054,
#  'repayment_date': {'number': 875, 'median': '12/31/2999'},
#  '2_yr_default_rate_denom': 5123,
#  '3_yr_repayment_suppressed': {'no_pell_grant': 0.8384201077,
#   'income': {'high_income': 0.8317572892,
#    'middle_income': 0.7998622115,
#    'low_income': 0.6885833831},
#   'non_completers': 0.6355640535,
#   'independent_students': 0.5848787447,
#   'non_first_generation_students': 0.7998503554,
#   'completers': 0.8719715492,
#   'first_generation_students': 0.7403846154,
#   'female_students': 0.7860775588,
#   'overall': 0.7850716896,
#   'pell_grant': 0.7203732504,
#   'male_students': 0.7842741935,
#   'dependent_students': 0.8069546234},
#  '3_yr_default_rate_denom': 4696}
